# %%
import numpy as np#importing libraries
import pandas as pd

# %%
match = pd.read_csv('matches.csv')#assigning a name 
delivery = pd.read_csv('deliveries.csv')

# %%
match.head()#used to know first 5 values of data
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
match.shape #It is used to know the total number of columns and rows
# Out:
# (1095, 20)

# %%
delivery.head() # to know first five data of dataset
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %%
delivery.shape # to know the number of rows and columns
# Out:
# (260920, 17)

# %%
match.info  # to know the all information about the dataset
# Out:
# <bound method DataFrame.info of            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
delivery.info #to know the information of the table
# Out:
# <bound method DataFrame.info of         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260915   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
# ...

# %%
total_score_df=delivery.groupby(['match_id','inning']).sum()['total_runs'].reset_index()# table_
#score_df is a dataframe

# %%
print(type(total_score_df))
print(total_score_df.head())#it displays first 5 rows of the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    match_id  inning  total_runs
# 0    335982       1         222
# 1    335982       2          82
# 2    335983       1         240
# 3    335983       2         207
# 4    335984       1         129

# %%
total_score_df = delivery.groupby(['match_id', 'inning'])['total_runs'].sum().reset_index()

# %%
total_score_df = total_score_df[total_score_df['inning'] == 1]

# %%
match_df = match.merge(total_score_df[['match_id','total_runs']],left_on='id',right_on='match_id')

# %%
match_df
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
match_df['team1'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Mumbai Indians', 'Kolkata Knight Riders',
#        'Rajasthan Royals', 'Deccan Chargers', 'Chennai Super Kings',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Gujarat Lions', 'Rising Pune Supergiants',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Punjab Kings',
#        'Lucknow Super Giants', 'Gujarat Titans',
#        'Royal Challengers Bengaluru'], dtype=object)

# %%
teams = [
    'Royal Challengers Bangalore',
    'Mumbai Indians',
    'Kolkata Knight Riders',
    'Delhi Capitals',
    'Sunrisers Hyderabad',
    'Lucknow Super Giants',
    'Gujarat Titans',
    'Chennai Super Kings'
]

# %%
match_df['team1'] = match_df['team1'].str.replace('Delhi Daredevils','Delhi Capitals')
match_df['team2'] = match_df['team2'].str.replace('Delhi Daredevils','Delhi Capitals')
#replacing the old team names with the new team names
match_df['team1'] = match_df['team1'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
match_df['team2'] = match_df['team2'].str.replace('Deccan Chargers','Sunrisers Hyderabad')

# %%
match_df = match_df[match_df['team1'].isin(teams)]
match_df = match_df[match_df['team1'].isin(teams)]

# %%
match_df.shape
# Out:
# (802, 22)

# %%
match_df
# Out:
#            id   season       city        date   match_type player_of_match  \
# 0      335982  2007/08  Bangalore  2008-04-18       League     BB McCullum
# 2      335984  2007/08      Delhi  2008-04-19       League     MF Maharoof
# 3      335985  2007/08     Mumbai  2008-04-20       League      MV Boucher
# 4      335986  2007/08    Kolkata  2008-04-20       League       DJ Hussey
# 6      335988  2007/08  Hyderabad  2008-04-22       League        V Sehwag
# ...       ...      ...        ...         ...          ...             ...
# 1086  1426302     2024      Delhi  2024-05-14       League        I Sharma
# 1088  1426305     2024     Mumbai  2024-05-17       League        N Pooran
# 1091  1426309     2024  Ahmedabad  2024-05-21  Qualifier 1        MA Starc
# 1093  1426311     2024    Chennai  2024-05-24  Qualifier 2   Shahbaz Ahmed
# 1094  1426312     2024    Chennai  2024-05-26        Final        MA Starc
#
# ...

# %%
match_df = match_df[['match_id','city','winner','total_runs']]

# %%
delivery_df = match_df.merge(delivery,on='match_id')

# %%
delivery_df=delivery_df[delivery_df['inning']==2]

# %%
delivery_df.shape
# Out:
# (92161, 20)

# %%
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders           222       2
# 125       335982  Bangalore  Kolkata Knight Riders           222       2
# 126       335982  Bangalore  Kolkata Knight Riders           222       2
# 127       335982  Bangalore  Kolkata Knight Riders           222       2
# 128       335982  Bangalore  Kolkata Knight Riders           222       2
# ...          ...        ...                    ...           ...     ...
# 191142   1426312    Chennai  Kolkata Knight Riders           113       2
# 191143   1426312    Chennai  Kolkata Knight Riders           113       2
# 191144   1426312    Chennai  Kolkata Knight Riders           113       2
# 191145   1426312    Chennai  Kolkata Knight Riders           113       2
# 191146   1426312    Chennai  Kolkata Knight Riders           113       2
#
#                        batting_team           bowling_team  over  ball  \
# ...

# %%
delivery_df['current_score']=delivery_df.groupby('match_id')['total_runs_y'].cumsum()
#cumulative sum

# %%
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders           222       2
# 125       335982  Bangalore  Kolkata Knight Riders           222       2
# 126       335982  Bangalore  Kolkata Knight Riders           222       2
# 127       335982  Bangalore  Kolkata Knight Riders           222       2
# 128       335982  Bangalore  Kolkata Knight Riders           222       2
# ...          ...        ...                    ...           ...     ...
# 191142   1426312    Chennai  Kolkata Knight Riders           113       2
# 191143   1426312    Chennai  Kolkata Knight Riders           113       2
# 191144   1426312    Chennai  Kolkata Knight Riders           113       2
# 191145   1426312    Chennai  Kolkata Knight Riders           113       2
# 191146   1426312    Chennai  Kolkata Knight Riders           113       2
#
#                        batting_team           bowling_team  over  ball  \
# ...

# %%
 delivery_df['runs_left']= delivery_df['total_runs_x'] - delivery_df['current_score']

# %%
 delivery_df['runs_left']
# Out:
# 124       221
# 125       220
# 126       220
# 127       219
# 128       218
#          ...
# 191142      3
# 191143      2
# 191144      1
# 191145      0
# 191146     -1
# Name: runs_left, Length: 92161, dtype: int64

# %%
 delivery_df
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders           222       2
# 125       335982  Bangalore  Kolkata Knight Riders           222       2
# 126       335982  Bangalore  Kolkata Knight Riders           222       2
# 127       335982  Bangalore  Kolkata Knight Riders           222       2
# 128       335982  Bangalore  Kolkata Knight Riders           222       2
# ...          ...        ...                    ...           ...     ...
# 191142   1426312    Chennai  Kolkata Knight Riders           113       2
# 191143   1426312    Chennai  Kolkata Knight Riders           113       2
# 191144   1426312    Chennai  Kolkata Knight Riders           113       2
# 191145   1426312    Chennai  Kolkata Knight Riders           113       2
# 191146   1426312    Chennai  Kolkata Knight Riders           113       2
#
#                        batting_team           bowling_team  over  ball  \
# ...

# %%
delivery_df['balls_left']=126 - (delivery_df['over']*6+delivery_df['ball'])

# %%
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders           222       2
# 125       335982  Bangalore  Kolkata Knight Riders           222       2
# 126       335982  Bangalore  Kolkata Knight Riders           222       2
# 127       335982  Bangalore  Kolkata Knight Riders           222       2
# 128       335982  Bangalore  Kolkata Knight Riders           222       2
# ...          ...        ...                    ...           ...     ...
# 191142   1426312    Chennai  Kolkata Knight Riders           113       2
# 191143   1426312    Chennai  Kolkata Knight Riders           113       2
# 191144   1426312    Chennai  Kolkata Knight Riders           113       2
# 191145   1426312    Chennai  Kolkata Knight Riders           113       2
# 191146   1426312    Chennai  Kolkata Knight Riders           113       2
#
#                        batting_team           bowling_team  over  ball  \
# ...

# %%
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].fillna("0")
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].apply(lambda x: 0 if x == "0" else 1)
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].astype(int)

wickets = delivery_df.groupby('match_id')['player_dismissed'].cumsum().values

delivery_df['wickets'] = 10 - wickets

delivery_df.head()
# Out:
#      match_id       city                 winner  total_runs_x  inning  \
# 124    335982  Bangalore  Kolkata Knight Riders           222       2
# 125    335982  Bangalore  Kolkata Knight Riders           222       2
# 126    335982  Bangalore  Kolkata Knight Riders           222       2
# 127    335982  Bangalore  Kolkata Knight Riders           222       2
# 128    335982  Bangalore  Kolkata Knight Riders           222       2
#
#                     batting_team           bowling_team  over  ball    batter  \
# 124  Royal Challengers Bangalore  Kolkata Knight Riders     0     1  R Dravid
# 125  Royal Challengers Bangalore  Kolkata Knight Riders     0     2  W Jaffer
# 126  Royal Challengers Bangalore  Kolkata Knight Riders     0     3  W Jaffer
# 127  Royal Challengers Bangalore  Kolkata Knight Riders     0     4  W Jaffer
# 128  Royal Challengers Bangalore  Kolkata Knight Riders     0     5  R Dravid
#
#      ... total_runs_y extras_type  is_wicket  player_dismissed  \
# ...

# %%
delivery_df.tail()
# Out:
#         match_id     city                 winner  total_runs_x  inning  \
# 191142   1426312  Chennai  Kolkata Knight Riders           113       2
# 191143   1426312  Chennai  Kolkata Knight Riders           113       2
# 191144   1426312  Chennai  Kolkata Knight Riders           113       2
# 191145   1426312  Chennai  Kolkata Knight Riders           113       2
# 191146   1426312  Chennai  Kolkata Knight Riders           113       2
#
#                  batting_team         bowling_team  over  ball   batter  ...  \
# 191142  Kolkata Knight Riders  Sunrisers Hyderabad     9     5  SS Iyer  ...
# 191143  Kolkata Knight Riders  Sunrisers Hyderabad     9     6  VR Iyer  ...
# 191144  Kolkata Knight Riders  Sunrisers Hyderabad    10     1  VR Iyer  ...
# 191145  Kolkata Knight Riders  Sunrisers Hyderabad    10     2  SS Iyer  ...
# 191146  Kolkata Knight Riders  Sunrisers Hyderabad    10     3  VR Iyer  ...
#
# ...

# %%
# current  run rate = runs/overs
delivery_df['crr']=(delivery_df['current_score']*6)/(120-delivery_df['balls_left'])

# %%
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders           222       2
# 125       335982  Bangalore  Kolkata Knight Riders           222       2
# 126       335982  Bangalore  Kolkata Knight Riders           222       2
# 127       335982  Bangalore  Kolkata Knight Riders           222       2
# 128       335982  Bangalore  Kolkata Knight Riders           222       2
# ...          ...        ...                    ...           ...     ...
# 191142   1426312    Chennai  Kolkata Knight Riders           113       2
# 191143   1426312    Chennai  Kolkata Knight Riders           113       2
# 191144   1426312    Chennai  Kolkata Knight Riders           113       2
# 191145   1426312    Chennai  Kolkata Knight Riders           113       2
# 191146   1426312    Chennai  Kolkata Knight Riders           113       2
#
#                        batting_team           bowling_team  over  ball  \
# ...

# %%
#required run rate = left_over runs/left over 
delivery_df['rrr'] = (delivery_df['runs_left']*6)/delivery_df['balls_left']

# %%
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders           222       2
# 125       335982  Bangalore  Kolkata Knight Riders           222       2
# 126       335982  Bangalore  Kolkata Knight Riders           222       2
# 127       335982  Bangalore  Kolkata Knight Riders           222       2
# 128       335982  Bangalore  Kolkata Knight Riders           222       2
# ...          ...        ...                    ...           ...     ...
# 191142   1426312    Chennai  Kolkata Knight Riders           113       2
# 191143   1426312    Chennai  Kolkata Knight Riders           113       2
# 191144   1426312    Chennai  Kolkata Knight Riders           113       2
# 191145   1426312    Chennai  Kolkata Knight Riders           113       2
# 191146   1426312    Chennai  Kolkata Knight Riders           113       2
#
#                        batting_team           bowling_team  over  ball  \
# ...

# %%
def result(row):
    return 1 if row['batting_team'] == row['winner'] else 0

# %%
delivery_df['result'] = delivery_df.apply(result,axis=1)

# %%
final_df = delivery_df[['batting_team','bowling_team','city','runs_left','balls_left','wickets','total_runs_x','crr','rrr','result']]

# %%
final_df=final_df.sample(final_df.shape[0])

# %%
final_df.sample()
# Out:
#                       batting_team           bowling_team       city  \
# 84357  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
#
#        runs_left  balls_left  wickets  total_runs_x   crr       rrr  result
# 84357        107         118       10           111  12.0  5.440678       1

# %%
final_df.dropna(inplace=True)

# %%
final_df =final_df[final_df['balls_left']!=0]

# %%
import numpy as np

final_df.replace([np.inf, -np.inf], np.nan, inplace=True)
final_df.dropna(inplace=True)

# %%
x=final_df.iloc[:,:-1]
y=final_df.iloc[:,-1]
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y)

# %%
x=final_df.iloc[:,:-1]
y=final_df.iloc[:,-1]
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=1)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

trf = ColumnTransformer([
    ('trf', OneHotEncoder(sparse_output=False, drop='first'),
     ['batting_team', 'bowling_team', 'city'])
], remainder='passthrough')

# %%
x_train
# Out:
#                        batting_team           bowling_team       city  \
# 59320           Chennai Super Kings          Pune Warriors    Chennai
# 168106               Mumbai Indians  Kolkata Knight Riders     Mumbai
# 178364          Chennai Super Kings         Gujarat Titans  Ahmedabad
# 158587                 Punjab Kings   Lucknow Super Giants       Pune
# 18024   Royal Challengers Bangalore  Kolkata Knight Riders  Centurion
# ...                             ...                    ...        ...
# 103349             Delhi Daredevils    Sunrisers Hyderabad      Delhi
# 130054        Kolkata Knight Riders         Mumbai Indians  Abu Dhabi
# 81782         Kolkata Knight Riders       Delhi Daredevils      Delhi
# 87776         Kolkata Knight Riders         Mumbai Indians     Mumbai
# 41484              Delhi Daredevils    Chennai Super Kings    Chennai
#
#         runs_left  balls_left  wickets  total_runs_x        crr        rrr
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

# %%
pipe = Pipeline(steps=[
    ('step11',trf),
    ('step2',LogisticRegression(solver='liblinear'))
])

# %%
y_train
# Out:
# 59320     0
# 168106    1
# 178364    1
# 158587    0
# 18024     1
#          ..
# 103349    1
# 130054    0
# 81782     1
# 87776     0
# 41484     0
# Name: result, Length: 69361, dtype: int64

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

trf = ColumnTransformer([
    ('trf', OneHotEncoder(sparse_output=False, drop='first'),
     ['batting_team', 'bowling_team', 'city'])
], remainder='passthrough')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

# %%
pipe = Pipeline(steps=[
    ('step11',trf),
    ('step2',LogisticRegression(solver='liblinear'))
])

# %%
numeric_cols = x_train.select_dtypes(include=np.number).columns

np.isinf(x_train[numeric_cols]).sum()
# Out:
# runs_left       0
# balls_left      0
# wickets         0
# total_runs_x    0
# crr             0
# rrr             0
# dtype: int64

# %%
numeric_cols = x_train.select_dtypes(include=np.number).columns

for col in numeric_cols:
    print(col, np.isinf(x_train[col]).sum())
# Out:
# runs_left 0
# balls_left 0
# wickets 0
# total_runs_x 0
# crr 0
# rrr 0

# %%
import numpy as np

final_df.replace([np.inf, -np.inf], np.nan, inplace=True)
final_df.dropna(inplace=True)

# %%
import numpy as np

for col in x_train.select_dtypes(include=np.number).columns:
    print(col)
    print("Inf:", np.isinf(x_train[col]).sum())
    print("Max:", x_train[col].max())
    print("Min:", x_train[col].min())
    print()
# Out:
# runs_left
# Inf: 0
# Max: 286
# Min: -16
#
# balls_left
# Inf: 0
# Max: 125
# Min: 3
#
# wickets
# Inf: 0
# Max: 10
# Min: 0
#
# total_runs_x
# Inf: 0
# Max: 287
# Min: 62
#
# crr
# Inf: 0
# Max: 162.0
# Min: -132.0
#
# rrr
# Inf: 0
# Max: 130.0
# Min: -9.0

# %%
print(x_train.columns)
# Out:
# Index(['batting_team', 'bowling_team', 'city', 'runs_left', 'balls_left',
#        'wickets', 'total_runs_x', 'crr', 'rrr'],
#       dtype='object')

# %%
final_df.replace([np.inf, -np.inf], np.nan).isnull().sum()
# Out:
# batting_team    0
# bowling_team    0
# city            0
# runs_left       0
# balls_left      0
# wickets         0
# total_runs_x    0
# crr             0
# rrr             0
# result          0
# dtype: int64

# %%
import numpy as np

for col in x_train.select_dtypes(include=np.number).columns:
    print(col, np.isinf(x_train[col]).sum())
# Out:
# runs_left 0
# balls_left 0
# wickets 0
# total_runs_x 0
# crr 0
# rrr 0

# %%
x_train.isnull().sum()
# Out:
# batting_team    0
# bowling_team    0
# city            0
# runs_left       0
# balls_left      0
# wickets         0
# total_runs_x    0
# crr             0
# rrr             0
# dtype: int64

# %%
import numpy as np

final_df.replace([np.inf, -np.inf], np.nan, inplace=True)
final_df.dropna(inplace=True)

# %%
X = final_df.drop('result', axis=1)
y = final_df['result']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    random_state=1
)

# %%
pipe.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('step11',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
from sklearn.metrics import accuracy_score

y_pred = pipe.predict(x_test)

accuracy_score(y_test, y_pred)
# Out:
# 0.8129865636353152

# %%
pipe.predict_proba(x_test)
# Out:
# array([[0.42737782, 0.57262218],
#        [0.93059137, 0.06940863],
#        [0.85297567, 0.14702433],
#        ...,
#        [0.32084243, 0.67915757],
#        [0.02787235, 0.97212765],
#        [0.00778373, 0.99221627]], shape=(17341, 2))

# %%
import pickle

pickle.dump(pipe, open('pipe.pkl', 'wb'))

# %%
teams = delivery_df['batting_team'].unique().tolist()

pickle.dump(teams, open('teams.pkl', 'wb'))

# %%
cities = delivery_df['city'].dropna().unique().tolist()

pickle.dump(cities, open('cities.pkl', 'wb'))
